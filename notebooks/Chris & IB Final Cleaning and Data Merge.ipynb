# %%
import pandas as pd
import numpy as np
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')

# %%
nyc_coll_csv = "../data/rawdata/final_coll_data_df.csv"
dark_sky_csv1 = "../data/rawdata/dark_sky_1.csv"
dark_sky_csv2 = "../data/rawdata/dark_sky_3.csv" 

nyc_coll = pd.read_csv(nyc_coll_csv)
dark_sky_1 = pd.read_csv(dark_sky_csv1)
dark_sky_2 = pd.read_csv(dark_sky_csv2)

# %%
#nyc_coll

# %%
#dark_sky_1

# %%
#dark_sky_2

# %%
frames = [dark_sky_1, dark_sky_2]
dark_sky_df = pd.concat(frames, ignore_index=True)
dark_sky_df.reset_index
dark_sky_df
# Out:
#              Day               Detail  Moonphase  \
# 0     1388512800    partly-cloudy-day       0.97
# 1     1388599200    partly-cloudy-day       0.02
# 2     1388685600                  fog       0.05
# 3     1388772000                  fog       0.09
# 4     1388858400  partly-cloudy-night       0.12
# 5     1388944800                 rain       0.16
# 6     1389031200                 rain       0.20
# 7     1389117600            clear-day       0.23
# 8     1389204000  partly-cloudy-night       0.27
# 9     1389290400  partly-cloudy-night       0.30
# 10    1389376800                 rain       0.33
# 11    1389463200                 rain       0.36
# 12    1389549600    partly-cloudy-day       0.40
# 13    1389636000  partly-cloudy-night       0.43
# 14    1389722400                 rain       0.45
# 15    1389808800                  fog       0.48
# 16    1389895200               cloudy       0.52
# 17    1389981600  partly-cloudy-night       0.55
# ...

# %%
dark_sky_df = dark_sky_df.rename(columns={'Day': 'UNIX DATE'})
dark_sky_df.head()
# Out:
#     UNIX DATE               Detail  Moonphase  \
# 0  1388512800    partly-cloudy-day       0.97
# 1  1388599200    partly-cloudy-day       0.02
# 2  1388685600                  fog       0.05
# 3  1388772000                  fog       0.09
# 4  1388858400  partly-cloudy-night       0.12
#
#                              Summary     Sunrise      Sunset  cloudCover  \
# 0       Mostly cloudy until evening.  1388492470  1388525969        0.47
# 1  Mostly cloudy throughout the day.  1388578876  1388612417        0.44
# 2     Foggy starting in the evening.  1388665281  1388698868        1.00
# 3              Foggy in the morning.  1388751683  1388785319        0.54
# 4      Partly cloudy in the evening.  1388838083  1388871773        0.12
#
#    dewPoint  humidity  precipIntensity    ...      precipProbability  \
# 0     12.98      0.57           0.0000    ...                   0.00
# 1     14.62      0.56           0.0000    ...                   0.00
# ...

# %%
coll_n_weather = pd.merge(nyc_coll, dark_sky_df, on="UNIX DATE", how='inner')
coll_n_weather
# Out:
#         UNIX DATE        DATE  HOUR        DAY  MONTH  YEAR        BOROUGH  \
# 0      1546279200  12/31/2018    18     Monday     12  2018          BRONX
# 1      1546279200  12/31/2018    18     Monday     12  2018          BRONX
# 2      1546279200  12/31/2018    18     Monday     12  2018       BROOKLYN
# 3      1546279200  12/31/2018    18     Monday     12  2018       BROOKLYN
# 4      1546279200  12/31/2018    18     Monday     12  2018  STATEN ISLAND
# 5      1546279200  12/31/2018    18     Monday     12  2018            NaN
# 6      1546279200  12/31/2018    18     Monday     12  2018            NaN
# 7      1546279200  12/31/2018    18     Monday     12  2018         QUEENS
# 8      1546279200  12/31/2018    18     Monday     12  2018            NaN
# 9      1546192800  12/30/2018    18     Sunday     12  2018       BROOKLYN
# 10     1546192800  12/30/2018    18     Sunday     12  2018       BROOKLYN
# ...

# %%
coll_n_weather.columns
# Out:
# Index(['UNIX DATE', 'DATE', 'HOUR', 'DAY', 'MONTH', 'YEAR', 'BOROUGH',
#        'DEATHS', 'INJURIES', 'ZIP CODE', 'LATITUDE', 'LONGITUDE', 'LOCATION',
#        'Detail', 'Moonphase', 'Summary', 'Sunrise', 'Sunset', 'cloudCover',
#        'dewPoint', 'humidity', 'precipIntensity', 'precipIntensityMax',
#        'precipProbability', 'pressure', 'temperatureMax', 'temperatureMaxTime',
#        'temperatureMin', 'temperatureMinTime', 'visibility', 'windGust',
#        'windGustTime', 'windSpeed'],
#       dtype='object')

# %%
coll_n_weather.to_csv("../data/cleandata/coll_n_weather.csv", index = False, header = True)
