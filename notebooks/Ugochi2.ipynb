# %%
import pandas as pd
import numpy as np
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
file= "../data/cleandata/coll_n_weather.csv" 

coll_n_weather = pd.read_csv(file)
coll_n_weather.head()
# Out:
#     UNIX DATE        DATE  HOUR     DAY  MONTH  YEAR        BOROUGH  DEATHS  \
# 0  1546279200  12/31/2018    18  Monday     12  2018          BRONX     0.0
# 1  1546279200  12/31/2018    18  Monday     12  2018          BRONX     0.0
# 2  1546279200  12/31/2018    18  Monday     12  2018       BROOKLYN     0.0
# 3  1546279200  12/31/2018    18  Monday     12  2018       BROOKLYN     0.0
# 4  1546279200  12/31/2018    18  Monday     12  2018  STATEN ISLAND     0.0
#
#    INJURIES  ZIP CODE    ...      precipProbability  pressure temperatureMax  \
# 0         0   10454.0    ...                    1.0   1024.06          45.56
# 1         0   10471.0    ...                    1.0   1024.06          45.56
# 2         0   11203.0    ...                    1.0   1024.06          45.56
# 3         0   11219.0    ...                    1.0   1024.06          45.56
# 4         0   10301.0    ...                    1.0   1024.06          45.56
#
# ...

# %%
coll_n_weather["Summary"].value_counts()
# Out:
# Mostly cloudy throughout the day.                                        2125
# Clear throughout the day.                                                1488
# Mostly cloudy until evening.                                              827
# Partly cloudy throughout the day.                                         743
# Partly cloudy until evening.                                              623
# Partly cloudy starting in the afternoon, continuing until evening.        620
# Overcast throughout the day.                                              544
# Mostly cloudy until afternoon.                                            483
# Partly cloudy in the morning.                                             475
# Mostly cloudy starting in the afternoon.                                  433
# Partly cloudy starting in the afternoon.                                  386
# Mostly cloudy in the morning.                                             385
# ...

# %%
summary_data= coll_n_weather[["Summary", "INJURIES", "DEATHS"]]
summary_group=summary_data.groupby("Summary")
summary_group.sum().head()
# Out:
#                                                     INJURIES  DEATHS
# Summary
# Clear throughout the day.                                366     2.0
# Foggy in the afternoon.                                    3     0.0
# Foggy in the evening.                                      0     0.0
# Foggy in the morning and humid throughout the day.         2     0.0
# Foggy in the morning.                                     58     0.0

# %%
#test bar grapy Injuries vs weather summary. DO we want this???

x_axis = np.arange(len(coll_n_weather))
tick_locations = [value+0.4 for value in x_axis]

x_axis= coll_n_weather["Summary"]
height1= coll_n_weather["INJURIES"]
height2= coll_n_weather["DEATHS"]
width=0.8

p1= plt.bar(x_axis, height1, width, bottom=None, align='center', data=None)
p2= plt.bar(x_axis, height2, width, bottom=height1, align='center', data=None)

plt.ylabel('Number of Injuries and Deaths')
plt.title('Number of Injuries and Deaths vs. Weather Summary')
#plt.xticks(i)
#plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Injuries', 'Deaths'))


plt.show()

# %%
#Number of Persons Injured vs. Months

# %%
plt
